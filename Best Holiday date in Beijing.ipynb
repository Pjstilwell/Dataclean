# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

from pandas import *
beijing = read_csv('Beijing_PEK_2014.csv', skipinitialspace=True)

import datetime
date = datetime.date.today()
date
datetime.date(2013, 11, 12)
beijing.loc(1)

# %%
beijing['Date'] = to_datetime(beijing['Date'])
beijing.index = beijing['Date']
beijing['Mean TemperatureC'].plot()

# %%
# The best months for temperature are clearly June, July August so we will work with those.

# %%
bestMonths = beijing.loc[datetime.date(2014,6,1):datetime.date(2014,8,31)]
bestMonths['Mean TemperatureC'].plot()

# %%
# The best two weeks are clearly towards the end of July. Now we will look at rain as well.

# %%
bestMonths[['Mean TemperatureC','Precipitationmm']].plot()

# %%
# Conclusion
# The best two weeks are end of July since there is little to no rain and the temperature is the best.
